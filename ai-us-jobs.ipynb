# %%
import pandas as pd

# %%
df=pd.read_excel("all_data_M_2024.xlsx")

# %%
# Convert dataframe from excel to csv
df.to_csv('all_data_M_2024.csv')

# %%
# Clean up the read.csv call, having trouble reading the file
# Set ** values to NA
df = pd.read_csv("all_data_M_2024.csv", na_values='**')
# Out:
# /var/folders/y5/lnw79n7s6pxdg8p4fslsq4cc0000gn/T/ipykernel_9438/1598862688.py:3: DtypeWarning: Columns (5,17,31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("all_data_M_2024.csv", na_values='**')

# %%
df
# Out:
#         Unnamed: 0     AREA  \
# 0                0       99
# 1                1       99
# 2                2       99
# 3                3       99
# 4                4       99
# ...            ...      ...
# 409512      409512  4800004
# 409513      409513  5500001
# 409514      409514  5500002
# 409515      409515  5500003
# 409516      409516  5500004
#
#                                                AREA_TITLE  AREA_TYPE  \
# 0                                                    U.S.          1
# 1                                                    U.S.          1
# 2                                                    U.S.          1
# 3                                                    U.S.          1
# 4                                                    U.S.          1
# ...                                                   ...        ...
# 409512  Hill Country Region of Texas nonmetropolitan area          6
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# AREA              int64
# AREA_TITLE       object
# AREA_TYPE         int64
# PRIM_STATE       object
# NAICS            object
# NAICS_TITLE      object
# I_GROUP          object
# OWN_CODE          int64
# OCC_CODE         object
# OCC_TITLE        object
# O_GROUP          object
# TOT_EMP         float64
# EMP_PRSE        float64
# JOBS_1000       float64
# LOC_QUOTIENT    float64
# PCT_TOTAL       float64
# PCT_RPT          object
# H_MEAN           object
# A_MEAN           object
# MEAN_PRSE        object
# H_PCT10          object
# H_PCT25          object
# H_MEDIAN         object
# H_PCT75          object
# H_PCT90          object
# A_PCT10          object
# A_PCT25          object
# A_MEDIAN         object
# A_PCT75          object
# A_PCT90          object
# ANNUAL           object
# HOURLY           object
# dtype: object

# %%
# Isolate to only evaluate national data, not state data
US = df[df['PRIM_STATE']=='US']
# See full display
pd.set_option("display.max_columns", None)

# %%
US
# Out:
#         Unnamed: 0  AREA AREA_TITLE  AREA_TYPE PRIM_STATE   NAICS  \
# 0                0    99       U.S.          1         US       0
# 1                1    99       U.S.          1         US       0
# 2                2    99       U.S.          1         US       0
# 3                3    99       U.S.          1         US       0
# 4                4    99       U.S.          1         US       0
# ...            ...   ...        ...        ...        ...     ...
# 177819      177819    99       U.S.          1         US  5320A1
# 177820      177820    99       U.S.          1         US  5320A1
# 177821      177821    99       U.S.          1         US  5320A1
# 177822      177822    99       U.S.          1         US  5320A1
# 177823      177823    99       U.S.          1         US  5320A1
#
#                                               NAICS_TITLE         I_GROUP  \
# 0                                          Cross-industry  cross-industry
# ...

# %%
US.sort_values(by="TOT_EMP", ascending=False)
# Out:
#         Unnamed: 0  AREA AREA_TITLE  AREA_TYPE PRIM_STATE   NAICS  \
# 0                0    99       U.S.          1         US       0
# 1                1    99       U.S.          1         US       0
# 2                2    99       U.S.          1         US       0
# 3                3    99       U.S.          1         US       0
# 4                4    99       U.S.          1         US       0
# ...            ...   ...        ...        ...        ...     ...
# 177819      177819    99       U.S.          1         US  5320A1
# 177820      177820    99       U.S.          1         US  5320A1
# 177821      177821    99       U.S.          1         US  5320A1
# 177822      177822    99       U.S.          1         US  5320A1
# 177823      177823    99       U.S.          1         US  5320A1
#
#                                               NAICS_TITLE         I_GROUP  \
# 0                                          Cross-industry  cross-industry
# ...

# %%
pd.set_option("display.max_rows", 100)

# %%
US.sort_values(by="TOT_EMP", ascending=False).head(100)
# Out:
#         Unnamed: 0  AREA AREA_TITLE  AREA_TYPE PRIM_STATE   NAICS  \
# 0                0    99       U.S.          1         US       0
# 1403          1403    99       U.S.          1         US       1
# 12086        12086    99       U.S.          1         US      62
# 162181      162181    99       U.S.          1         US  999001
# 834            834    99       U.S.          1         US       0
# 174631      174631    99       U.S.          1         US   44-45
# 2222          2222    99       U.S.          1         US       1
# 167977      167977    99       U.S.          1         US  999301
# 13801        13801    99       U.S.          1         US      72
# 111523      111523    99       U.S.          1         US  611000
# 10996        10996    99       U.S.          1         US      61
# 1312          1312    99       U.S.          1         US       0
# 680            680    99       U.S.          1         US       0
# ...
